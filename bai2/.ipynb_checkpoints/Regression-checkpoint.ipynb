# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import r2_score

# %%
data = pd.read_csv("bmw.csv", sep=",")
data.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0   5 Series  2014  11200    Automatic    67068   Diesel  125  57.6
# 1   6 Series  2018  27000    Automatic    14827   Petrol  145  42.8
# 2   5 Series  2016  16000    Automatic    62794   Diesel  160  51.4
# 3   1 Series  2017  12750    Automatic    26676   Diesel  145  72.4
# 4   7 Series  2014  14500    Automatic    39554   Diesel  160  50.4
#
#    engineSize
# 0         2.0
# 1         2.0
# 2         3.0
# 3         1.5
# 4         3.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10781 entries, 0 to 10780
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         10781 non-null  object
#  1   year          10781 non-null  int64
#  2   price         10781 non-null  int64
#  3   transmission  10781 non-null  object
#  4   mileage       10781 non-null  int64
#  5   fuelType      10781 non-null  object
#  6   tax           10781 non-null  int64
#  7   mpg           10781 non-null  float64
#  8   engineSize    10781 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 758.2+ KB

# %%
data.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  10781.000000   10781.000000   10781.000000  10781.000000  10781.000000
# mean    2017.078935   22733.408867   25496.986550    131.702068     56.399035
# std        2.349038   11415.528189   25143.192559     61.510755     31.336958
# min     1996.000000    1200.000000       1.000000      0.000000      5.500000
# 25%     2016.000000   14950.000000    5529.000000    135.000000     45.600000
# 50%     2017.000000   20462.000000   18347.000000    145.000000     53.300000
# 75%     2019.000000   27940.000000   38206.000000    145.000000     62.800000
# max     2020.000000  123456.000000  214000.000000    580.000000    470.800000
#
#          engineSize
# count  10781.000000
# mean       2.167767
# std        0.552054
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        2.000000
# max        6.600000

# %%
data.isnull().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
data.tail()
# Out:
#            model  year  price transmission  mileage fuelType  tax   mpg  \
# 10776         X3  2016  19000    Automatic    40818   Diesel  150  54.3
# 10777   5 Series  2016  14600    Automatic    42947   Diesel  125  60.1
# 10778   3 Series  2017  13100       Manual    25468   Petrol  200  42.8
# 10779   1 Series  2014   9930    Automatic    45000   Diesel   30  64.2
# 10780         X1  2017  15981    Automatic    59432   Diesel  125  57.6
#
#        engineSize
# 10776         2.0
# 10777         2.0
# 10778         2.0
# 10779         2.0
# 10780         2.0

# %%
data.corr()["price"].sort_values()
# Out:
# mileage      -0.605397
# mpg          -0.204882
# tax           0.263484
# engineSize    0.460196
# year          0.623756
# price         1.000000
# Name: price, dtype: float64

# %%
data_model = data.model
data_price = data.price
#Visiualization
plt.figure(figsize=(45,20))
sns.barplot(x = data_model, y = data_price)
plt.xticks(rotation = 90) # rotation of countries's names
plt.xlabel('Model')
plt.ylabel('Price')
plt.title('Model/Price')
plt.show()

# %%
plt.figure(figsize=(13,7))
sns.distplot(data["price"])
plt.show()
# Out:
# C:\Users\man28\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(13,7))
sns.countplot(data.year)
plt.show()
# Out:
# C:\Users\man28\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(13,7))
sns.scatterplot(x=data.mileage, y=data.price, data=data)
plt.show()

# %%
data.sort_values('price', ascending=False).head(20)
# Out:
#           model  year   price transmission  mileage fuelType  tax   mpg  \
# 3638   2 Series  2015  123456    Semi-Auto    33419   Diesel   20  68.9
# 5362         M4  2016   99950    Automatic      771   Petrol  300  33.2
# 2909         M4  2017   89990    Semi-Auto     1336   Petrol  145  33.2
# 4776         M5  2019   89900    Semi-Auto     2269   Petrol  145  24.1
# 1813   8 Series  2019   88980    Semi-Auto       88   Petrol  145  24.4
# 721    8 Series  2019   84898    Semi-Auto     3185   Petrol  145  24.4
# 5877         M5  2019   81140    Semi-Auto      551   Petrol  145  24.1
# 6115   8 Series  2020   79991    Semi-Auto      151   Diesel  145  26.7
# 7024         X7  2020   79566    Semi-Auto     1000   Petrol  145  24.8
# 2602         X7  2020   78490    Semi-Auto     4919   Diesel  145  31.4
# 6446         X7  2019   78386    Automatic     1793   Diesel  145  31.4
# 241          X7  2020   78000    Semi-Auto     5000   Diesel  150  31.4
# 7112         X7  2020   77995    Semi-Auto     7500   Diesel  150  31.4
# 2542         X7  2020   77990    Semi-Auto     5656   Diesel  150  31.4
# 2938         X7  2019   77880    Semi-Auto     6506   Diesel  145  31.4
# 2544         X7  2019   77880    Semi-Auto     6506   Diesel  150  31.4
# 7394         M4  2016   76990    Automatic     4550   Petrol  300  33.2
# 1704         X7  2019   76970    Semi-Auto       10   Diesel  145  31.4
# 5173   8 Series  2020   74995    Semi-Auto     4500   Diesel  145  26.7
# 809          X7  2019   74990    Semi-Auto     9200   Diesel  145  31.4
#
#       engineSize
# 3638         2.0
# 5362         3.0
# 2909         3.0
# 4776         4.4
# 1813         4.4
# 721          4.4
# 5877         4.4
# 6115         3.0
# 7024         3.0
# 2602         3.0
# 6446         3.0
# 241          3.0
# 7112         3.0
# 2542         3.0
# 2938         3.0
# 2544         3.0
# 7394         3.0
# 1704         3.0
# 5173         3.0
# 809          3.0

# %%
data.sort_values('price', ascending=True).head(20)
# Out:
#            model  year  price transmission  mileage fuelType  tax   mpg  \
# 9744    3 Series  1999   1200    Automatic    82000   Petrol  245  31.0
# 9696    3 Series  2004   1445       Manual   162000   Diesel  205  49.6
# 9554    1 Series  2007   1500       Manual   167000   Diesel  125  57.6
# 10006   3 Series  2000   1550    Automatic    93000   Petrol  270  29.7
# 7284    5 Series  2002   1595    Automatic   115000   Petrol  325  28.5
# 9406    5 Series  2000   1699       Manual    99209   Petrol  265  29.4
# 9963          Z4  2004   1995       Manual   114000   Petrol  325  32.1
# 10009   3 Series  2002   2350       Manual    99000   Petrol  325  30.1
# 9220    3 Series  2007   2375       Manual    94000   Petrol  240  38.7
# 9918    1 Series  2010   2450       Manual   117454   Diesel   30  62.8
# 7358    1 Series  2004   2495       Manual   112000   Diesel  200  49.6
# 10714   3 Series  2005   2499       Manual   130000   Petrol  315  31.4
# 10028   5 Series  2007   2499    Automatic   129000   Diesel  330  35.8
# 7428    3 Series  2006   2500       Manual   105000   Petrol  240  38.7
# 10021   3 Series  2007   2550       Manual   103000   Diesel  205  49.6
# 9289    3 Series  2008   2675       Manual   130000   Petrol  155  46.3
# 10019   3 Series  2006   2795       Manual    76000   Diesel  160  50.4
# 8307    3 Series  2004   2888       Manual   133175   Petrol  300  36.2
# 9248    1 Series  2006   2990       Manual    88000   Petrol  260  37.7
# 9874    3 Series  2002   2990       Manual   121821   Petrol  330  29.4
#
#        engineSize
# 9744          2.8
# 9696          2.0
# 9554          2.0
# 10006         2.5
# 7284          2.2
# 9406          2.0
# 9963          2.2
# 10009         2.2
# 9220          2.0
# 9918          2.0
# 7358          2.0
# 10714         2.5
# 10028         2.5
# 7428          2.0
# 10021         2.0
# 9289          2.0
# 10019         2.0
# 8307          2.0
# 9248          1.6
# 9874          2.5

# %%
len(data)
# Out:
# 10781

# %%
nnpDf = data.sort_values("price",ascending = False).iloc[131:]
nnpDf
# Out:
#            model  year  price transmission  mileage fuelType  tax   mpg  \
# 5791          X6  2019  61854    Semi-Auto     1000   Diesel  145  34.9
# 1907          M5  2019  61797    Semi-Auto     4419   Petrol  145  26.9
# 5598          M5  2018  61792    Automatic     5856   Petrol  145  26.9
# 6374          X5  2019  61682    Semi-Auto    10782   Diesel  145  33.6
# 7768          X5  2019  61550    Automatic    11311   Diesel  150  33.6
# ...          ...   ...    ...          ...      ...      ...  ...   ...
# 7284    5 Series  2002   1595    Automatic   115000   Petrol  325  28.5
# 10006   3 Series  2000   1550    Automatic    93000   Petrol  270  29.7
# 9554    1 Series  2007   1500       Manual   167000   Diesel  125  57.6
# 9696    3 Series  2004   1445       Manual   162000   Diesel  205  49.6
# 9744    3 Series  1999   1200    Automatic    82000   Petrol  245  31.0
#
#        engineSize
# 5791          3.0
# 1907          4.4
# 5598          4.4
# 6374          3.0
# 7768          3.0
# ...           ...
# 7284          2.2
# 10006         2.5
# 9554          2.0
# 9696          2.0
# 9744          2.8
#
# [10650 rows x 9 columns]

# %%
nnpDf.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  10650.000000  10650.000000   10650.000000  10650.000000  10650.000000
# mean    2017.053709  22151.985446   25757.890798    131.521596     56.565944
# std        2.350922  10164.803578   25182.186861     61.817077     31.201617
# min     1996.000000   1200.000000       1.000000      0.000000      5.500000
# 25%     2016.000000  14800.500000    5664.250000    131.250000     46.300000
# 50%     2017.000000  20046.000000   18935.000000    145.000000     53.300000
# 75%     2019.000000  27491.500000   38558.250000    145.000000     62.800000
# max     2020.000000  61854.000000  214000.000000    580.000000    470.800000
#
#          engineSize
# count  10650.000000
# mean       2.155324
# std        0.538507
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        2.000000
# max        6.600000

# %%
plt.figure(figsize=(13,7))
sns.distplot(nnpDf["price"])
plt.show()
# Out:
# C:\Users\man28\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
nnpDf.groupby('year').mean()['price']
# Out:
# year
# 1996     5995.000000
# 1997     3950.000000
# 1998     3950.000000
# 1999     3285.000000
# 2000     1624.500000
# 2001     7333.333333
# 2002     5486.500000
# 2003     9222.500000
# 2004     8213.166667
# 2005     5390.166667
# 2006     5252.714286
# 2007     4830.500000
# 2008     6240.043478
# 2009     6618.100000
# 2010     7490.390244
# 2011     9099.098039
# 2012     9533.689076
# 2013    11118.355742
# 2014    13323.598802
# 2015    15082.211726
# 2016    16561.987234
# 2017    19226.056977
# 2018    22571.665089
# 2019    29988.122605
# 2020    33840.706134
# Name: price, dtype: float64

# %%
nnpDf[nnpDf.year != 1970].groupby("year").mean()["price"]
# Out:
# year
# 1996     5995.000000
# 1997     3950.000000
# 1998     3950.000000
# 1999     3285.000000
# 2000     1624.500000
# 2001     7333.333333
# 2002     5486.500000
# 2003     9222.500000
# 2004     8213.166667
# 2005     5390.166667
# 2006     5252.714286
# 2007     4830.500000
# 2008     6240.043478
# 2009     6618.100000
# 2010     7490.390244
# 2011     9099.098039
# 2012     9533.689076
# 2013    11118.355742
# 2014    13323.598802
# 2015    15082.211726
# 2016    16561.987234
# 2017    19226.056977
# 2018    22571.665089
# 2019    29988.122605
# 2020    33840.706134
# Name: price, dtype: float64

# %%
nnpDf.drop('transmission', axis=1, inplace=True)
nnpDf.drop('fuelType', axis=1, inplace=True)
nnpDf.drop('model', axis=1,inplace=True)

# %%
df = nnpDf
df.head()
# Out:
#       year  price  mileage  tax   mpg  engineSize
# 5791  2019  61854     1000  145  34.9         3.0
# 1907  2019  61797     4419  145  26.9         4.4
# 5598  2018  61792     5856  145  26.9         4.4
# 6374  2019  61682    10782  145  33.6         3.0
# 7768  2019  61550    11311  150  33.6         3.0

# %%
X = df.drop('price', axis=1).values
y = df['price'].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state = 0)

# %%
from sklearn.ensemble import RandomForestRegressor
random_forest_reg = RandomForestRegressor(n_estimators = 50, random_state= 0 ) # n_estimators = numbor of estimator tree
random_forest_reg.fit(X_train, y_train)
y_pred_rf_reg = random_forest_reg.predict(X_test)

# %%
print(f'y_test: {y_test}\nprediction: {y_pred_rf_reg}')
# Out:
# y_test: [13995 41994 19798 ... 27990 20172 21980]
# prediction: [16971.64 50248.12 19445.82 ... 29601.5  18581.04 22054.62]

# %%
print('R Square Score for Random Forest Regression : ', r2_score(y_test, y_pred_rf_reg))
# Out:
# R Square Score for Random Forest Regression :  0.889437954745661

# %%
df.head(20)
# Out:
#       year  price  mileage  tax   mpg  engineSize
# 5791  2019  61854     1000  145  34.9         3.0
# 1907  2019  61797     4419  145  26.9         4.4
# 5598  2018  61792     5856  145  26.9         4.4
# 6374  2019  61682    10782  145  33.6         3.0
# 7768  2019  61550    11311  150  33.6         3.0
# 7272  2020  61485     6374  145  26.7         3.0
# 3544  2019  61083     2151  145  33.6         3.0
# 6958  2020  60995      100  145  24.8         3.0
# 362   2020  60990     3500  145  33.6         3.0
# 7897  2019  60000     8000  145  33.6         3.0
# 7825  2019  60000     8700  145  37.7         3.0
# 6270  2020  59999     3000  150  28.5         3.0
# 3655  2020  59995        5  145  34.0         3.0
# 6516  2019  59995     4741  145  24.8         3.0
# 4571  2019  59995     1501  145  41.5         3.0
# 7297  2019  59995      101  145  34.9         3.0
# 4585  2020  59995     1501  145  31.7         3.0
# 5949  2020  59995      700  145  31.7         3.0
# 3045  2020  59993      500  145  37.7         3.0
# 7010  2019  59991     4509  145  34.9         3.0

# %%
print(random_forest_reg.predict([[2020, 1000, 140, 29.2, 4.0]]))
# Out:
# [55605.38]

# %%
df.tail(20)
# Out:
#        year  price  mileage  tax   mpg  engineSize
# 9248   2006   2990    88000  260  37.7         1.6
# 9874   2002   2990   121821  330  29.4         2.5
# 8307   2004   2888   133175  300  36.2         2.0
# 10019  2006   2795    76000  160  50.4         2.0
# 9289   2008   2675   130000  155  46.3         2.0
# 10021  2007   2550   103000  205  49.6         2.0
# 7428   2006   2500   105000  240  38.7         2.0
# 10028  2007   2499   129000  330  35.8         2.5
# 10714  2005   2499   130000  315  31.4         2.5
# 7358   2004   2495   112000  200  49.6         2.0
# 9918   2010   2450   117454   30  62.8         2.0
# 9220   2007   2375    94000  240  38.7         2.0
# 10009  2002   2350    99000  325  30.1         2.2
# 9963   2004   1995   114000  325  32.1         2.2
# 9406   2000   1699    99209  265  29.4         2.0
# 7284   2002   1595   115000  325  28.5         2.2
# 10006  2000   1550    93000  270  29.7         2.5
# 9554   2007   1500   167000  125  57.6         2.0
# 9696   2004   1445   162000  205  49.6         2.0
# 9744   1999   1200    82000  245  31.0         2.8

# %%
print(random_forest_reg.predict([[2000, 90000, 290, 30.4, 3.0]]))
# Out:
# [4888.]

# %% [markdown]
# Nhận xét: Lựa chọn thuật toán random forest regression vì tập dữ liệu lớn, có nhiều thuộc tính. R Square Score tương đối cao.
